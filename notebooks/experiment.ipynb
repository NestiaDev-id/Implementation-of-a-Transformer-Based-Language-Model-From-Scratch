# %%
print(f"Cleaned data written to")
# Out:
# Cleaned data written to

# %%
import pandas as pd
from pathlib import Path

# Sesuaikan path dengan lokasi file Anda
file_path = Path("E:/Dataset/Wmt14/de-en/wmt14_translate_de-en_train.csv")

if file_path.exists():
    # Membaca hanya 10 baris pertama
    df_preview = pd.read_csv(file_path, nrows=10, encoding='utf-8')
        
    print(f"📊 Preview file: {file_path.name}")
    print("-" * 30)
    # Menampilkan tabel
    display(df_preview) 
    
    # Menampilkan nama kolom jika ada
    print(f"\nNama kolom yang ditemukan: {df_preview.columns.tolist()}")
else:
    print(f"❌ File tidak ditemukan di: {file_path}")
# Out:
# 📊 Preview file: wmt14_translate_de-en_train.csv
# ------------------------------
#                                                   de  \
# 0  An der B 211 befindet sich in Loyermoor der so...
# 1  Ich begrüße die Erklärung des Herrn Kommissar ...
# 2  Das ist das Gegenteil von dem, was getan werde...
# 3                                                  .
# 4  The Ethnographical museum in Varna is in a hou...
# 5  Bis vor kurzem war das nur ein Traum. Aber glü...
# 6  Neue Einstellung "Scrollen durch Cursorbewegun...
# 7  Es besteht überhaupt kein Anlass, diese Vorsch...
# 8  Es ist das bekannteste arabische Bauwerk auf d...
# 9  Es ist klar, dass ein Moratorium nur die zweit...
#
#                                                   en
# 0  Here the largest town of the district is locat...
# 1  I should like, in passing, to pay tribute to t...
# 2  That is the opposite of what should be done an...
# 3                                                  .
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       7 from tqdm import tqdm
#       9 # --- Konfigurasi ---
# ---> 10 BASE_DIR = Path(__file__).resolve().parent.parent
#      11 RAW_DATA_SOURCE = Path("E:/Dataset/Wmt14/de-en")
#      12 MIN_LEN = 20
#
# NameError: name '__file__' is not defined
